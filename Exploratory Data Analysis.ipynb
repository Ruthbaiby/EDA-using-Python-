# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/USER/Documents/NCD_RisC_Lancet_2016_BP_age_standardised_countries.csv")

# %%
#1 Understanding the data

# %%
data.head()
# Out:
#   Country/Region/World  ISO  Sex  Year  Mean systolic blood pressure (mmHg)  \
# 0          Afghanistan  AFG  Men  1975                           121.078635
# 1          Afghanistan  AFG  Men  1976                           121.213135
# 2          Afghanistan  AFG  Men  1977                           121.352221
# 3          Afghanistan  AFG  Men  1978                           121.493430
# 4          Afghanistan  AFG  Men  1979                           121.636602
#
#    Mean systolic blood pressure lower 95% uncertainty interval (mmHg)  \
# 0                                         110.560019
# 1                                         111.237480
# 2                                         111.913929
# 3                                         112.391051
# 4                                         112.922056
#
#    Mean systolic blood pressure upper 95% uncertainty interval (mmHg)  \
# 0                                         131.280612
# ...

# %%
data.tail()
# Out:
#       Country/Region/World  ISO    Sex  Year  \
# 16395             Zimbabwe  ZWE  Women  2011
# 16396             Zimbabwe  ZWE  Women  2012
# 16397             Zimbabwe  ZWE  Women  2013
# 16398             Zimbabwe  ZWE  Women  2014
# 16399             Zimbabwe  ZWE  Women  2015
#
#        Mean systolic blood pressure (mmHg)  \
# 16395                           128.940075
# 16396                           128.888469
# 16397                           128.838725
# 16398                           128.790787
# 16399                           128.742671
#
#        Mean systolic blood pressure lower 95% uncertainty interval (mmHg)  \
# 16395                                         123.068150
# 16396                                         122.551047
# 16397                                         122.010757
# 16398                                         121.435755
# 16399                                         120.784644
#
# ...

# %%
data.describe()
# Out:
#               Year  Mean systolic blood pressure (mmHg)  \
# count  16400.00000                         16400.000000
# mean    1995.00000                           126.834377
# std       11.83252                             4.275440
# min     1975.00000                           111.239134
# 25%     1985.00000                           123.907540
# 50%     1995.00000                           127.054019
# 75%     2005.00000                           129.796233
# max     2015.00000                           137.936117
#
#        Mean systolic blood pressure lower 95% uncertainty interval (mmHg)  \
# count                                       16400.000000
# mean                                          121.257973
# std                                             4.712228
# min                                           103.790189
# 25%                                           118.158218
# 50%                                           121.358058
# ...

# %%
data.shape
# Out:
# (16400, 13)

# %%
data.columns
# Out:
# Index(['Country/Region/World', 'ISO', 'Sex', 'Year',
#        'Mean systolic blood pressure (mmHg)',
#        'Mean systolic blood pressure lower 95% uncertainty interval (mmHg)',
#        'Mean systolic blood pressure upper 95% uncertainty interval (mmHg)',
#        'Mean diastolic blood pressure (mmHg)',
#        'Mean diastolic blood pressure lower 95% uncertainty interval (mmHg)',
#        'Mean diastolic blood pressure upper 95% uncertainty interval (mmHg)',
#        'Prevalence of raised blood pressure',
#        'Prevalence of raised blood pressure lower 95% uncertainty interval',
#        'Prevalence of raised blood pressure upper 95% uncertainty interval'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Country/Region/World                                                     200
# ISO                                                                      200
# Sex                                                                        2
# Year                                                                      41
# Mean systolic blood pressure (mmHg)                                    16400
# Mean systolic blood pressure lower 95% uncertainty interval (mmHg)     16400
# Mean systolic blood pressure upper 95% uncertainty interval (mmHg)     16400
# Mean diastolic blood pressure (mmHg)                                   16400
# Mean diastolic blood pressure lower 95% uncertainty interval (mmHg)    16400
# Mean diastolic blood pressure upper 95% uncertainty interval (mmHg)    16400
# Prevalence of raised blood pressure                                    16400
# Prevalence of raised blood pressure lower 95% uncertainty interval     16400
# ...

# %%
data['Sex'].unique
# Out:
# <bound method Series.unique of 0          Men
# 1          Men
# 2          Men
# 3          Men
# 4          Men
#          ...
# 16395    Women
# 16396    Women
# 16397    Women
# 16398    Women
# 16399    Women
# Name: Sex, Length: 16400, dtype: object>

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# Country/Region/World                                                   0
# ISO                                                                    0
# Sex                                                                    0
# Year                                                                   0
# Mean systolic blood pressure (mmHg)                                    0
# Mean systolic blood pressure lower 95% uncertainty interval (mmHg)     0
# Mean systolic blood pressure upper 95% uncertainty interval (mmHg)     0
# Mean diastolic blood pressure (mmHg)                                   0
# Mean diastolic blood pressure lower 95% uncertainty interval (mmHg)    0
# Mean diastolic blood pressure upper 95% uncertainty interval (mmHg)    0
# Prevalence of raised blood pressure                                    0
# Prevalence of raised blood pressure lower 95% uncertainty interval     0
# Prevalence of raised blood pressure upper 95% uncertainty interval     0
# dtype: int64

# %%
patients= data.drop(['Mean systolic blood pressure lower 95% uncertainty interval (mmHg)',
       'Mean systolic blood pressure upper 95% uncertainty interval (mmHg)',
       'Mean diastolic blood pressure (mmHg)',
       'Mean diastolic blood pressure lower 95% uncertainty interval (mmHg)',
       'Mean diastolic blood pressure upper 95% uncertainty interval (mmHg)',
       'Prevalence of raised blood pressure',
       'Prevalence of raised blood pressure lower 95% uncertainty interval',
       'Prevalence of raised blood pressure upper 95% uncertainty interval'], axis=1)

# %%
patients.head()
# Out:
#   Country/Region/World  ISO  Sex  Year  Mean systolic blood pressure (mmHg)
# 0          Afghanistan  AFG  Men  1975                           121.078635
# 1          Afghanistan  AFG  Men  1976                           121.213135
# 2          Afghanistan  AFG  Men  1977                           121.352221
# 3          Afghanistan  AFG  Men  1978                           121.493430
# 4          Afghanistan  AFG  Men  1979                           121.636602

# %%
#3 relationship analysis

# %%
correlation= patients.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(patients)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 sns.relplot(x='year',y= 'ISO', hue='sex',data= patients)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
